# %%
import pandas as pd
df = pd.read_csv("dataset.csv")

# %%
# Task 1: Data Overview

# Step 1: Import pandas
import pandas as pd

# Step 2: Load your dataset
df = pd.read_csv("dataset.csv")  

# Step 3: Display the first 5 rows
print("🔹 First 5 Rows of the Dataset:")
print(df.head())

# Step 4: Display dataset structure and data types
print("\n🔹 Dataset Info:")
df.info()

# Step 5: Summary statistics for numeric columns
print("\n🔹 Summary Statistics:")
print(df.describe())

# Step 6: Column names
print("\n🔹 Column Names:")
print(df.columns.tolist())

# Step 7: Check for missing values
print("\n🔹 Missing Values:")
print(df.isnull().sum())

# Step 8: Shape of the dataset
print("\n🔹 Dataset Shape (Rows, Columns):")
print(df.shape)
# Out:
# 🔹 First 5 Rows of the Dataset:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
# ...

# %% [markdown]
# ## ✅ Task 1: Data Overview Summary
#
# ### 🔍 Objective:
# Understand the structure, data types, and completeness of the dataset.
#
# ---
#
# ### 📊 Key Findings:
# - **Total Records:** 40
# - **Total Columns:** 24
# - **No Missing Values** – All columns are complete.
# - **Column Types:**
#   - 8 numerical columns (`int64`)
#   - 16 categorical/text columns (`object`)
#
# ---
#
# ### 📋 Top 5 Rows Preview:
# (Displayed using `df.head()`)
#
# ---
#
# ### 🧾 Useful Stats:
# - **Age Range:** 21 to 35 (Mean = 27.8)
# - **Mutual Fund Score:** Mean = 2.55
# - **Gold and Fixed Deposits** are among the most preferred avenues.
#
# ---
#
# ### 🚫 Issues Noted:
# - Column **`Stock_Marktet`** appears to have a typo — likely meant to be `Stock_Market`.
